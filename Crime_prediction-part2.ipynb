# %% [markdown]
# ## Import and preprocess

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

import warnings
warnings.simplefilter(action='ignore')

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('crimedata.csv',encoding='latin-1',na_values=["?"])
df.head()
# Out:
#             Êcommunityname state  countyCode  communityCode  fold  population  \
# 0  BerkeleyHeightstownship    NJ        39.0         5320.0     1       11980
# 1           Marpletownship    PA        45.0        47616.0     1       23123
# 2               Tigardcity    OR         NaN            NaN     1       29344
# 3         Gloversvillecity    NY        35.0        29443.0     1       16656
# 4              Bemidjicity    MN         7.0         5068.0     1       11245
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  racePctHisp  \
# 0           3.10          1.37         91.78          6.50         1.88
# 1           2.82          0.80         95.57          3.44         0.85
# 2           2.43          0.74         94.33          3.43         2.35
# 3           2.40          1.70         97.35          0.50         0.70
# 4           2.76          0.53         89.16          1.17         0.52
#
#    agePct12t21  agePct12t29  agePct16t24  agePct65up  numbUrban  pctUrban  \
# 0        12.47        21.44        10.93       11.33      11980     100.0
# 1        11.01        21.30        10.48       17.18      23123     100.0
# 2        11.36        25.88        11.01       10.28      29344     100.0
# 3        12.55        25.20        12.19       17.57          0       0.0
# 4        24.46        40.53        28.69       12.65          0       0.0
#
#    medIncome  pctWWage  pctWFarmSelf  pctWInvInc  pctWSocSec  pctWPubAsst  \
# 0      75122     89.24          1.55       70.20       23.62         1.03
# 1      47917     78.99          1.11       64.11       35.50         2.75
# 2      35669     82.00          1.15       55.73       22.25         2.94
# 3      20580     68.15          0.24       38.95       39.48        11.71
# 4      17390     69.33          0.55       42.82       32.16        11.21
#
#    pctWRetire  medFamInc  perCapInc  whitePerCap  blackPerCap  indianPerCap  \
# 0       18.39      79584      29711        30233        13600          5725
# 1       22.85      55323      20148        20191        18137             0
# 2       14.56      42112      16946        17103        16644         21606
# 3       18.33      26501      10810        10909         9984          4941
# 4       14.43      24018       8483         9009          887          4425
#
#    AsianPerCap  OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  \
# 0        27101       5115.0       22838          227            1.96
# 1        20074       5250.0       12222          885            3.98
# 2        15528       5954.0        8405         1389            4.75
# 3         3541       2451.0        4391         2831           17.23
# 4         3352       3000.0        1328         2855           29.99
#
#    PctLess9thGrade  PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  \
# 0             5.81          9.90        48.18           2.70      64.55
# 1             5.61         13.72        29.89           2.43      61.96
# 2             2.80          9.09        30.13           4.01      69.80
# 3            11.05         33.68        10.81           9.86      54.74
# 4            12.15         23.06        25.28           9.08      52.44
#
#    PctEmplManu  PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  \
# 0        14.65            28.82          5.49             50.73
# 1        12.26            29.28          6.39             37.64
# 2        15.95            21.52          8.79             32.48
# 3        31.22            27.43         26.76             22.71
# 4         6.89            36.54         10.94             27.80
#
#    MalePctDivorce  MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  \
# 0            3.67           26.38          5.22         4.47        3.22
# 1            4.23           27.99          6.45         5.42        3.11
# 2           10.10           25.78         14.76        12.55        2.95
# 3           10.98           28.15         14.47        12.91        2.98
# 4            7.51           50.66         11.64         9.73        2.98
#
#    PctFam2Par  PctKids2Par  PctYoungKids2Par  PctTeen2Par  \
# 0       91.43        90.17             95.78        95.81
# 1       86.91        85.33             96.82        86.46
# 2       78.54        78.85             92.37        75.72
# 3       64.02        62.36             65.38        67.43
# 4       58.59        55.20             66.51        79.17
#
#    PctWorkMomYoungKids  PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  \
# 0                44.56       58.88                   31                 0.36
# 1                51.14       62.43                   43                 0.24
# 2                66.08       74.19                  164                 0.88
# 3                59.59       70.27                  561                 3.84
# 4                61.22       68.94                  402                 4.70
#
#    NumImmig  PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  \
# 0      1277            8.69         13.00         20.99          30.93
# 1      1920            5.21          8.65         13.33          22.50
# 2      1468           16.42         23.98         32.08          35.63
# 3       339           13.86         13.86         15.34          15.34
# 4       196           46.94         56.12         67.86          69.90
#
#    PctRecentImmig  PctRecImmig5  PctRecImmig8  PctRecImmig10  \
# 0            0.93          1.39          2.24           3.30
# 1            0.43          0.72          1.11           1.87
# 2            0.82          1.20          1.61           1.78
# 3            0.28          0.28          0.31           0.31
# 4            0.82          0.98          1.18           1.22
#
#    PctSpeakEnglOnly  PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  \
# 0             85.68                 1.37             4.81               4.17
# 1             87.79                 1.81             4.25               3.34
# 2             93.11                 1.14             2.97               2.05
# 3             94.98                 0.56             3.93               2.56
# 4             94.64                 0.39             5.23               3.11
#
#    PersPerOccupHous  PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  \
# 0              2.99               3.00                2.84            91.46
# 1              2.70               2.83                1.96            89.03
# 2              2.42               2.69                2.06            64.18
# 3              2.37               2.51                2.20            58.18
# 4              2.35               2.55                2.12            58.13
#
#    PctPersDenseHous  PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  \
# 0              0.39           11.06         3          64         98.37
# 1              1.01           23.60         3         240         97.15
# 2              2.03           47.46         3         544         95.68
# 3              1.21           45.66         3         669         91.19
# 4              2.94           55.64         2         333         92.45
#
#    PctHousOwnOcc  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0          91.01              3.12           37.50            1959
# 1          84.88              0.00           18.33            1958
# 2          57.79              0.92            7.54            1976
# 3          54.89              2.54           57.85            1939
# 4          53.57              3.90           42.64            1958
#
#    PctHousNoPhone  PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  \
# 0            0.00            0.28          215900        262600
# 1            0.31            0.14          136300        164200
# 2            1.55            0.12           74700         90400
# 3            7.00            0.87           36400         49600
# 4            7.45            0.82           30600         43200
#
#    OwnOccHiQuart  OwnOccQrange  RentLowQ  RentMedian  RentHighQ  RentQrange  \
# 0         326900        111000       685        1001       1001         316
# 1         199900         63600       467         560        672         205
# 2         112000         37300       370         428        520         150
# 3          66500         30100       195         250        309         114
# 4          59500         28900       202         283        362         160
#
#    MedRent  MedRentPctHousInc  MedOwnCostPctInc  MedOwnCostPctIncNoMtg  \
# 0     1001               23.8              21.1                   14.0
# 1      627               27.6              20.7                   12.5
# 2      484               24.1              21.7                   11.6
# 3      333               28.7              20.6                   14.5
# 4      332               32.2              23.2                   12.9
#
#    NumInShelters  NumStreet  PctForeignBorn  PctBornSameState  PctSameHouse85  \
# 0             11          0           10.66             53.72           65.29
# 1              0          0            8.30             77.17           71.27
# 2             16          0            5.00             44.77           36.60
# 3              0          0            2.04             88.71           56.70
# 4              2          0            1.74             73.75           42.22
#
#    PctSameCity85  PctSameState85  LemasSwornFT  LemasSwFTPerPop  \
# 0          78.09           89.14           NaN              NaN
# 1          90.22           96.12           NaN              NaN
# 2          61.26           82.85           NaN              NaN
# 3          90.17           96.24           NaN              NaN
# 4          60.34           89.02           NaN              NaN
#
#    LemasSwFTFieldOps  LemasSwFTFieldPerPop  LemasTotalReq  LemasTotReqPerPop  \
# 0                NaN                   NaN            NaN                NaN
# 1                NaN                   NaN            NaN                NaN
# 2                NaN                   NaN            NaN                NaN
# 3                NaN                   NaN            NaN                NaN
# 4                NaN                   NaN            NaN                NaN
#
#    PolicReqPerOffic  PolicPerPop  RacialMatchCommPol  PctPolicWhite  \
# 0               NaN          NaN                 NaN            NaN
# 1               NaN          NaN                 NaN            NaN
# 2               NaN          NaN                 NaN            NaN
# 3               NaN          NaN                 NaN            NaN
# 4               NaN          NaN                 NaN            NaN
#
#    PctPolicBlack  PctPolicHisp  PctPolicAsian  PctPolicMinor  \
# 0            NaN           NaN            NaN            NaN
# 1            NaN           NaN            NaN            NaN
# 2            NaN           NaN            NaN            NaN
# 3            NaN           NaN            NaN            NaN
# 4            NaN           NaN            NaN            NaN
#
#    OfficAssgnDrugUnits  NumKindsDrugsSeiz  PolicAveOTWorked  LandArea  \
# 0                  NaN                NaN               NaN       6.5
# 1                  NaN                NaN               NaN      10.6
# 2                  NaN                NaN               NaN      10.6
# 3                  NaN                NaN               NaN       5.2
# 4                  NaN                NaN               NaN      11.5
#
#    PopDens  PctUsePubTrans  PolicCars  PolicOperBudg  LemasPctPolicOnPatr  \
# 0   1845.9            9.63        NaN            NaN                  NaN
# 1   2186.7            3.84        NaN            NaN                  NaN
# 2   2780.9            4.37        NaN            NaN                  NaN
# 3   3217.7            3.31        NaN            NaN                  NaN
# 4    974.2            0.38        NaN            NaN                  NaN
#
#    LemasGangUnitDeploy  LemasPctOfficDrugUn  PolicBudgPerPop  murders  \
# 0                  NaN                  0.0              NaN        0
# 1                  NaN                  0.0              NaN        0
# 2                  NaN                  0.0              NaN        3
# 3                  NaN                  0.0              NaN        0
# 4                  NaN                  0.0              NaN        0
#
#    murdPerPop  rapes  rapesPerPop  robberies  robbbPerPop  assaults  \
# 0         0.0    0.0         0.00        1.0         8.20       4.0
# 1         0.0    1.0         4.25        5.0        21.26      24.0
# 2         8.3    6.0        16.60       56.0       154.95      14.0
# 3         0.0   10.0        57.86       10.0        57.86      33.0
# 4         0.0    NaN          NaN        4.0        32.04      14.0
#
#    assaultPerPop  burglaries  burglPerPop  larcenies  larcPerPop  autoTheft  \
# 0          32.81        14.0       114.85      138.0     1132.08       16.0
# 1         102.05        57.0       242.37      376.0     1598.78       26.0
# 2          38.74       274.0       758.14     1797.0     4972.19      136.0
# 3         190.93       225.0      1301.78      716.0     4142.56       47.0
# 4         112.14        91.0       728.93     1060.0     8490.87       91.0
#
#    autoTheftPerPop  arsons  arsonsPerPop  ViolentCrimesPerPop  nonViolPerPop
# 0           131.26     2.0         16.41                41.02        1394.59
# 1           110.55     1.0          4.25               127.56        1955.95
# 2           376.30    22.0         60.87               218.59        6167.51
# 3           271.93     NaN           NaN               306.64            NaN
# 4           728.93     5.0         40.05                  NaN        9988.79

# %%
df = df.rename(columns={'Êcommunityname':'communityName'})

# %% [markdown]
# ## Delete dependent variable

# %%
df.drop(columns=['murders' ,'murdPerPop' ,'rapes',
 'rapesPerPop' ,'robberies' ,'robbbPerPop' ,'assaults' ,'assaultPerPop',
 'burglaries' ,'burglPerPop' ,'larcenies' ,'larcPerPop' ,'autoTheft',
 'autoTheftPerPop' ,'arsons' ,'arsonsPerPop' ,'nonViolPerPop'],inplace=True)

# %% [markdown]
# * Extra columns added ['OwnOccQrange,RentQrange']

# %%
df.drop(columns=['communityName','countyCode' ,'communityCode' ,'fold'],inplace=True)

# %%
df.shape
# Out:
# (2215, 126)

# %%
list_col = df.columns.values
print(list_col)
# Out:
# ['state' 'population' 'householdsize' 'racepctblack' 'racePctWhite'
#  'racePctAsian' 'racePctHisp' 'agePct12t21' 'agePct12t29' 'agePct16t24'
#  'agePct65up' 'numbUrban' 'pctUrban' 'medIncome' 'pctWWage' 'pctWFarmSelf'
#  'pctWInvInc' 'pctWSocSec' 'pctWPubAsst' 'pctWRetire' 'medFamInc'
#  'perCapInc' 'whitePerCap' 'blackPerCap' 'indianPerCap' 'AsianPerCap'
#  'OtherPerCap' 'HispPerCap' 'NumUnderPov' 'PctPopUnderPov'
#  'PctLess9thGrade' 'PctNotHSGrad' 'PctBSorMore' 'PctUnemployed'
#  'PctEmploy' 'PctEmplManu' 'PctEmplProfServ' 'PctOccupManu'
#  'PctOccupMgmtProf' 'MalePctDivorce' 'MalePctNevMarr' 'FemalePctDiv'
#  'TotalPctDiv' 'PersPerFam' 'PctFam2Par' 'PctKids2Par' 'PctYoungKids2Par'
#  'PctTeen2Par' 'PctWorkMomYoungKids' 'PctWorkMom' 'NumKidsBornNeverMar'
#  'PctKidsBornNeverMar' 'NumImmig' 'PctImmigRecent' 'PctImmigRec5'
#  'PctImmigRec8' 'PctImmigRec10' 'PctRecentImmig' 'PctRecImmig5'
#  'PctRecImmig8' 'PctRecImmig10' 'PctSpeakEnglOnly' 'PctNotSpeakEnglWell'
#  'PctLargHouseFam' 'PctLargHouseOccup' 'PersPerOccupHous'
#  'PersPerOwnOccHous' 'PersPerRentOccHous' 'PctPersOwnOccup'
#  'PctPersDenseHous' 'PctHousLess3BR' 'MedNumBR' 'HousVacant'
#  'PctHousOccup' 'PctHousOwnOcc' 'PctVacantBoarded' 'PctVacMore6Mos'
#  'MedYrHousBuilt' 'PctHousNoPhone' 'PctWOFullPlumb' 'OwnOccLowQuart'
#  'OwnOccMedVal' 'OwnOccHiQuart' 'OwnOccQrange' 'RentLowQ' 'RentMedian'
#  'RentHighQ' 'RentQrange' 'MedRent' 'MedRentPctHousInc' 'MedOwnCostPctInc'
#  'MedOwnCostPctIncNoMtg' 'NumInShelters' 'NumStreet' 'PctForeignBorn'
#  'PctBornSameState' 'PctSameHouse85' 'PctSameCity85' 'PctSameState85'
#  'LemasSwornFT' 'LemasSwFTPerPop' 'LemasSwFTFieldOps'
#  'LemasSwFTFieldPerPop' 'LemasTotalReq' 'LemasTotReqPerPop'
#  'PolicReqPerOffic' 'PolicPerPop' 'RacialMatchCommPol' 'PctPolicWhite'
#  'PctPolicBlack' 'PctPolicHisp' 'PctPolicAsian' 'PctPolicMinor'
#  'OfficAssgnDrugUnits' 'NumKindsDrugsSeiz' 'PolicAveOTWorked' 'LandArea'
#  'PopDens' 'PctUsePubTrans' 'PolicCars' 'PolicOperBudg'
#  'LemasPctPolicOnPatr' 'LemasGangUnitDeploy' 'LemasPctOfficDrugUn'
#  'PolicBudgPerPop' 'ViolentCrimesPerPop']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Columns: 126 entries, state to ViolentCrimesPerPop
# dtypes: float64(98), int64(27), object(1)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#          population  householdsize  racepctblack  racePctWhite  racePctAsian  \
# 25%          343.350000   149.150000           79.435000      76.230000
# 50%          443.200000   196.000000           87.930000      86.180000
# 75%          637.250000   260.650000           93.645000      93.340000
# max         2162.500000  3437.200000          100.000000     100.000000
#
#        PctPolicBlack  PctPolicHisp  PctPolicAsian  PctPolicMinor  \
# count     343.000000    343.000000     343.000000     343.000000
# mean        9.263294      5.459767       0.681283      15.242245
# std        11.021424     10.604533       1.706344      14.826756
# min         0.000000      0.000000       0.000000       0.000000
# 25%         2.020000      0.415000       0.000000       4.950000
# 50%         5.000000      2.040000       0.000000      11.370000
# 75%        14.065000      6.215000       0.650000      19.740000
# max        67.310000     98.400000      18.570000      98.400000
#
#        OfficAssgnDrugUnits  NumKindsDrugsSeiz  PolicAveOTWorked     LandArea  \
# count           343.000000         343.000000        343.000000  2215.000000
# mean             26.288630           8.816327        119.114286    27.419955
# std             100.821921           2.836391         92.495186   109.822600
# min               0.000000           1.000000          0.000000     0.900000
# 25%               6.000000           7.000000         55.100000     7.300000
# 50%              12.000000           9.000000         98.700000    13.700000
# 75%              23.000000          10.500000        153.550000    26.100000
# max            1773.000000          15.000000        634.700000  3569.800000
#
#             PopDens  PctUsePubTrans    PolicCars  PolicOperBudg  \
# count   2215.000000     2215.000000   343.000000   3.430000e+02
# mean    2783.835034        3.041124   185.478134   3.217602e+07
# std     2828.993341        4.912917   318.542834   1.104566e+08
# min       10.000000        0.000000    20.000000   2.380215e+06
# 25%     1181.900000        0.360000    54.000000   7.275060e+06
# 50%     2027.300000        1.220000    86.000000   1.116411e+07
# 75%     3321.700000        3.365000   189.500000   2.014754e+07
# max    44229.900000       54.330000  3187.000000   1.617293e+09
#
#        LemasPctPolicOnPatr  LemasGangUnitDeploy  LemasPctOfficDrugUn  \
# count           343.000000           343.000000          2215.000000
# mean             87.130933             4.285714             0.980163
# std              10.349612             4.064538             2.877128
# min              10.850000             0.000000             0.000000
# 25%              84.295000             0.000000             0.000000
# 50%              89.580000             5.000000             0.000000
# 75%              93.200000            10.000000             0.000000
# max              99.940000            10.000000            48.440000
#
#        PolicBudgPerPop  ViolentCrimesPerPop
# count     3.430000e+02          1994.000000
# mean      1.535779e+05           589.078922
# std       2.030409e+05           614.784518
# min       1.526040e+04             0.000000
# 25%       8.809435e+04           161.700000
# 50%       1.145820e+05           374.060000
# 75%       1.556557e+05           794.400000
# max       2.422367e+06          4877.060000

# %%
df.describe(include=['O'])
# Out:
#        state
# count   2215
# unique    48
# top       CA
# freq     279

# %%
df.shape
# Out:
# (2215, 126)

# %% [markdown]
# # Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####  population vs ViolentCrimesPerPop

# %%
ax = sns.scatterplot(x="population", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
ax = sns.scatterplot(x="LandArea", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
ax = sns.scatterplot(x="LemasSwFTPerPop", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
ax = sns.scatterplot(x="racePctAsian", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
ax = sns.scatterplot(x="racepctblack", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
ax = sns.scatterplot(x="agePct12t29", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
ax = sns.scatterplot(x="agePct65up", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
crimedata_state_violent = df.groupby('state').agg({'ViolentCrimesPerPop':'mean'})[['ViolentCrimesPerPop']].reset_index()

# %%
plt.figure(figsize=(20,8))
ax = sns.barplot(x="state", y="ViolentCrimesPerPop", data=crimedata_state_violent)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.title('whitePerCap')
df['whitePerCap'].hist(bins='fd', density=True)
df['whitePerCap'].plot(kind='kde')


plt.subplot(3,2,2)
plt.title('blackPerCap')
df['blackPerCap'].hist(bins='fd', density=True)
df['blackPerCap'].plot(kind='kde')

plt.subplot(3,2,3)
plt.title('indianPerCap')
df['indianPerCap'].hist(bins='fd', density=True)
df['indianPerCap'].plot(kind='kde')



plt.subplot(3,2,4)
plt.title('AsianPerCap')

df['AsianPerCap'].hist(bins='fd', density=True)
df['AsianPerCap'].plot(kind='kde')


plt.subplot(3,2,5)

plt.title('HispPerCap')
df['HispPerCap'].hist(bins='fd', density=True)
df['HispPerCap'].plot(kind='kde')

plt.show()

# %% [markdown]
# ## Handling Missing value

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(30)
# Out:
#                       Total   Percent
# LemasSwFTFieldPerPop   1872  0.845147
# LemasTotalReq          1872  0.845147
# PolicReqPerOffic       1872  0.845147
# PolicPerPop            1872  0.845147
# RacialMatchCommPol     1872  0.845147
# PctPolicWhite          1872  0.845147
# PctPolicBlack          1872  0.845147
# PctPolicHisp           1872  0.845147
# PctPolicAsian          1872  0.845147
# PctPolicMinor          1872  0.845147
# OfficAssgnDrugUnits    1872  0.845147
# NumKindsDrugsSeiz      1872  0.845147
# PolicAveOTWorked       1872  0.845147
# LemasSwFTFieldOps      1872  0.845147
# LemasSwFTPerPop        1872  0.845147
# LemasSwornFT           1872  0.845147
# PolicCars              1872  0.845147
# PolicOperBudg          1872  0.845147
# LemasPctPolicOnPatr    1872  0.845147
# LemasGangUnitDeploy    1872  0.845147
# PolicBudgPerPop        1872  0.845147
# LemasTotReqPerPop      1872  0.845147
# ViolentCrimesPerPop     221  0.099774
# OtherPerCap               1  0.000451
# PctYoungKids2Par          0  0.000000
# NumUnderPov               0  0.000000
# PctPopUnderPov            0  0.000000
# PctLess9thGrade           0  0.000000
# PctNotHSGrad              0  0.000000
# PctBSorMore               0  0.000000

# %%
df = df.drop((missing_data[missing_data['Total'] > 500]).index,1)

# %%
df.shape
# Out:
# (2215, 104)

# %%
df = df.dropna(subset = ['ViolentCrimesPerPop'],axis=0)

# %%
# fill missing values for the select columns  with mean value
cols = ['OtherPerCap']
df.fillna(df[cols].mean(),inplace=True)

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(5)
# Out:
#                      Total  Percent
# ViolentCrimesPerPop      0      0.0
# LemasPctOfficDrugUn      0      0.0
# HispPerCap               0      0.0
# NumUnderPov              0      0.0
# PctPopUnderPov           0      0.0

# %%
df.shape
# Out:
# (1994, 104)

# %% [markdown]
# ## Convert categorical value to numerical

# %%
categorical_features = list(df.select_dtypes(include=['O']).columns)
categorical_features
# Out:
# ['state']

# %%
# Convert object datatype to categorical

for column in categorical_features:
    df[column] = df[column].astype('category')

# %%
# select the categorical columns 
category_columns = df.select_dtypes(['category']).columns

# convert each columns to code
df[category_columns] = df[category_columns].apply(lambda x: x.cat.codes)
df.head()
# Out:
#    state  population  householdsize  racepctblack  racePctWhite  racePctAsian  \
# 0     26       11980           3.10          1.37         91.78          6.50
# 1     33       23123           2.82          0.80         95.57          3.44
# 2     32       29344           2.43          0.74         94.33          3.43
# 3     29       16656           2.40          1.70         97.35          0.50
# 5     21      140494           2.45          2.51         95.65          0.90
#
#    racePctHisp  agePct12t21  agePct12t29  agePct16t24  agePct65up  numbUrban  \
# 0         1.88        12.47        21.44        10.93       11.33      11980
# 1         0.85        11.01        21.30        10.48       17.18      23123
# 2         2.35        11.36        25.88        11.01       10.28      29344
# 3         0.70        12.55        25.20        12.19       17.57          0
# 5         0.95        18.09        32.89        20.04       13.26     140494
#
#    pctUrban  medIncome  pctWWage  pctWFarmSelf  pctWInvInc  pctWSocSec  \
# 0     100.0      75122     89.24          1.55       70.20       23.62
# 1     100.0      47917     78.99          1.11       64.11       35.50
# 2     100.0      35669     82.00          1.15       55.73       22.25
# 3       0.0      20580     68.15          0.24       38.95       39.48
# 5     100.0      21577     75.78          1.00       41.15       29.31
#
#    pctWPubAsst  pctWRetire  medFamInc  perCapInc  whitePerCap  blackPerCap  \
# 0         1.03       18.39      79584      29711        30233        13600
# 1         2.75       22.85      55323      20148        20191        18137
# 2         2.94       14.56      42112      16946        17103        16644
# 3        11.71       18.33      26501      10810        10909         9984
# 5         7.12       14.09      27705      11878        12029         7382
#
#    indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  NumUnderPov  \
# 0          5725        27101       5115.0       22838          227
# 1             0        20074       5250.0       12222          885
# 2         21606        15528       5954.0        8405         1389
# 3          4941         3541       2451.0        4391         2831
# 5         10264        10753       7192.0        8104        23223
#
#    PctPopUnderPov  PctLess9thGrade  PctNotHSGrad  PctBSorMore  PctUnemployed  \
# 0            1.96             5.81          9.90        48.18           2.70
# 1            3.98             5.61         13.72        29.89           2.43
# 2            4.75             2.80          9.09        30.13           4.01
# 3           17.23            11.05         33.68        10.81           9.86
# 5           17.78             8.76         23.03        20.66           5.72
#
#    PctEmploy  PctEmplManu  PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  \
# 0      64.55        14.65            28.82          5.49             50.73
# 1      61.96        12.26            29.28          6.39             37.64
# 2      69.80        15.95            21.52          8.79             32.48
# 3      54.74        31.22            27.43         26.76             22.71
# 5      59.02        14.31            26.83         14.72             23.42
#
#    MalePctDivorce  MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  \
# 0            3.67           26.38          5.22         4.47        3.22
# 1            4.23           27.99          6.45         5.42        3.11
# 2           10.10           25.78         14.76        12.55        2.95
# 3           10.98           28.15         14.47        12.91        2.98
# 5           11.40           33.32         14.46        13.04        2.89
#
#    PctFam2Par  PctKids2Par  PctYoungKids2Par  PctTeen2Par  \
# 0       91.43        90.17             95.78        95.81
# 1       86.91        85.33             96.82        86.46
# 2       78.54        78.85             92.37        75.72
# 3       64.02        62.36             65.38        67.43
# 5       71.94        69.79             79.76        75.33
#
#    PctWorkMomYoungKids  PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  \
# 0                44.56       58.88                   31                 0.36
# 1                51.14       62.43                   43                 0.24
# 2                66.08       74.19                  164                 0.88
# 3                59.59       70.27                  561                 3.84
# 5                62.96       70.52                 1511                 1.58
#
#    NumImmig  PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  \
# 0      1277            8.69         13.00         20.99          30.93
# 1      1920            5.21          8.65         13.33          22.50
# 2      1468           16.42         23.98         32.08          35.63
# 3       339           13.86         13.86         15.34          15.34
# 5      2091           21.33         30.56         38.02          45.48
#
#    PctRecentImmig  PctRecImmig5  PctRecImmig8  PctRecImmig10  \
# 0            0.93          1.39          2.24           3.30
# 1            0.43          0.72          1.11           1.87
# 2            0.82          1.20          1.61           1.78
# 3            0.28          0.28          0.31           0.31
# 5            0.32          0.45          0.57           0.68
#
#    PctSpeakEnglOnly  PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  \
# 0             85.68                 1.37             4.81               4.17
# 1             87.79                 1.81             4.25               3.34
# 2             93.11                 1.14             2.97               2.05
# 3             94.98                 0.56             3.93               2.56
# 5             96.87                 0.60             3.08               1.92
#
#    PersPerOccupHous  PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  \
# 0              2.99               3.00                2.84            91.46
# 1              2.70               2.83                1.96            89.03
# 2              2.42               2.69                2.06            64.18
# 3              2.37               2.51                2.20            58.18
# 5              2.28               2.37                2.16            57.81
#
#    PctPersDenseHous  PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  \
# 0              0.39           11.06         3          64         98.37
# 1              1.01           23.60         3         240         97.15
# 2              2.03           47.46         3         544         95.68
# 3              1.21           45.66         3         669         91.19
# 5              2.11           53.19         2        5119         91.81
#
#    PctHousOwnOcc  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0          91.01              3.12           37.50            1959
# 1          84.88              0.00           18.33            1958
# 2          57.79              0.92            7.54            1976
# 3          54.89              2.54           57.85            1939
# 5          55.50              2.09           26.22            1966
#
#    PctHousNoPhone  PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  \
# 0            0.00            0.28          215900        262600
# 1            0.31            0.14          136300        164200
# 2            1.55            0.12           74700         90400
# 3            7.00            0.87           36400         49600
# 5            6.13            0.31           37700         53900
#
#    OwnOccHiQuart  OwnOccQrange  RentLowQ  RentMedian  RentHighQ  RentQrange  \
# 0         326900        111000       685        1001       1001         316
# 1         199900         63600       467         560        672         205
# 2         112000         37300       370         428        520         150
# 3          66500         30100       195         250        309         114
# 5          73100         35400       215         280        349         134
#
#    MedRent  MedRentPctHousInc  MedOwnCostPctInc  MedOwnCostPctIncNoMtg  \
# 0     1001               23.8              21.1                   14.0
# 1      627               27.6              20.7                   12.5
# 2      484               24.1              21.7                   11.6
# 3      333               28.7              20.6                   14.5
# 5      340               26.4              17.3                   11.7
#
#    NumInShelters  NumStreet  PctForeignBorn  PctBornSameState  PctSameHouse85  \
# 0             11          0           10.66             53.72           65.29
# 1              0          0            8.30             77.17           71.27
# 2             16          0            5.00             44.77           36.60
# 3              0          0            2.04             88.71           56.70
# 5            327          4            1.49             64.35           42.29
#
#    PctSameCity85  PctSameState85  LandArea  PopDens  PctUsePubTrans  \
# 0          78.09           89.14       6.5   1845.9            9.63
# 1          90.22           96.12      10.6   2186.7            3.84
# 2          61.26           82.85      10.6   2780.9            4.37
# 3          90.17           96.24       5.2   3217.7            3.31
# 5          70.61           85.66      70.4   1995.7            0.97
#
#    LemasPctOfficDrugUn  ViolentCrimesPerPop
# 0                  0.0                41.02
# 1                  0.0               127.56
# 2                  0.0               218.59
# 3                  0.0               306.64
# 5                  0.0               442.95

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(30,30))
n = 20
df_corr = df.corr()
columns = df_corr.nlargest(n, 'ViolentCrimesPerPop')['ViolentCrimesPerPop'].index
cm = np.corrcoef(df[columns].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=columns.values, xticklabels=columns.values)
plt.show()

# %%
df.shape
# Out:
# (1994, 104)

# %% [markdown]
# ## Modeling

# %%
y = df['ViolentCrimesPerPop']
X = df.drop(['ViolentCrimesPerPop'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
numerical_columns = X.drop('state',axis=1).columns.tolist()

# %%
X[numerical_columns] = scaler.fit_transform(X[numerical_columns])
# Out:
# /home/bat/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm = sm.add_constant(X_train)

# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit()

# %%
# Print a summary of the linear regression model obtained
print(lr.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.685
# Model:                             OLS   Adj. R-squared:                  0.664
# Method:                  Least Squares   F-statistic:                     32.17
# Date:                 Thu, 23 May 2019   Prob (F-statistic):          3.30e-304
# Time:                         20:38:21   Log-Likelihood:                -11599.
# No. Observations:                 1595   AIC:                         2.340e+04
# Df Residuals:                     1493   BIC:                         2.395e+04
# Df Model:                          101
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1517.2665    939.024      1.616      0.106    -324.680    3359.213
# state                    -3.1772      0.940     -3.381      0.001      -5.020      -1.334
# population            -2751.5016   1.78e+04     -0.155      0.877   -3.76e+04    3.21e+04
# householdsize          -131.2194    504.937     -0.260      0.795   -1121.681     859.242
# racepctblack            917.5319    364.943      2.514      0.012     201.675    1633.388
# racePctWhite             45.8764    344.944      0.133      0.894    -630.749     722.502
# racePctAsian             -7.7395    346.004     -0.022      0.982    -686.444     670.966
# racePctHisp             193.6321    334.669      0.579      0.563    -462.839     850.103
# agePct12t21            1086.3190    735.693      1.477      0.140    -356.782    2529.420
# agePct12t29           -1501.5527    878.071     -1.710      0.087   -3223.936     220.831
# agePct16t24            -401.2304   1245.269     -0.322      0.747   -2843.893    2041.432
# agePct65up             -263.2194    616.820     -0.427      0.670   -1473.145     946.707
# numbUrban             -1510.1466   1.75e+04     -0.086      0.931   -3.58e+04    3.28e+04
# pctUrban                109.5861     56.020      1.956      0.051      -0.299     219.471
# medIncome             -1245.6944    978.818     -1.273      0.203   -3165.698     674.309
# pctWWage               -764.2130    432.151     -1.768      0.077   -1611.901      83.475
# pctWFarmSelf            140.9889    117.272      1.202      0.229     -89.046     371.024
# pctWInvInc             -236.0707    241.548     -0.977      0.329    -709.879     237.738
# pctWSocSec              373.4799    473.448      0.789      0.430    -555.214    1302.173
# pctWPubAsst             316.3263    183.419      1.725      0.085     -43.460     676.112
# pctWRetire             -497.9105    180.259     -2.762      0.006    -851.498    -144.323
# medFamInc               803.0174    925.923      0.867      0.386   -1013.232    2619.266
# perCapInc               492.8726   1064.202      0.463      0.643   -1594.617    2580.362
# whitePerCap            -944.7328    890.574     -1.061      0.289   -2691.642     802.177
# blackPerCap            -258.0394    261.113     -0.988      0.323    -770.228     254.149
# indianPerCap           -527.0565    423.029     -1.246      0.213   -1356.851     302.738
# AsianPerCap             119.6665    119.897      0.998      0.318    -115.519     354.852
# OtherPerCap             459.2014    193.622      2.372      0.018      79.402     839.001
# HispPerCap               62.2207    122.996      0.506      0.613    -179.042     303.483
# NumUnderPov            1079.4912   4695.972      0.230      0.818   -8131.912    1.03e+04
# PctPopUnderPov         -246.3507    275.181     -0.895      0.371    -786.133     293.432
# PctLess9thGrade       -1103.4999    358.635     -3.077      0.002   -1806.983    -400.017
# PctNotHSGrad            831.4621    402.942      2.063      0.039      41.069    1621.856
# PctBSorMore             189.4786    291.423      0.650      0.516    -382.164     761.121
# PctUnemployed          -178.4592    212.474     -0.840      0.401    -595.238     238.319
# PctEmploy               731.2652    337.798      2.165      0.031      68.655    1393.875
# PctEmplManu            -165.3010    122.716     -1.347      0.178    -406.015      75.413
# PctEmplProfServ         -51.2963    180.931     -0.284      0.777    -406.201     303.609
# MedYrHousBuilt          -29.2455     88.521     -0.330      0.741    -202.885     144.394
# PctHousNoPhone           82.1772    153.028      0.537      0.591    -217.995     382.349
# PctWOFullPlumb            9.6558    160.560      0.060      0.952    -305.291     324.603
# OwnOccLowQuart         -294.7569    555.356     -0.531      0.596   -1384.118     794.604
# OwnOccMedVal            345.0171    887.066      0.389      0.697   -1395.011    2085.045
# OwnOccHiQuart          -349.7467    472.798     -0.740      0.460   -1277.165     577.672
# OwnOccQrange             37.9930    201.557      0.188      0.851    -357.373     433.359
# RentLowQ               -260.8124    214.943     -1.213      0.225    -682.435     160.810
# RentMedian              126.9095    483.635      0.262      0.793    -821.766    1075.585
# RentHighQ              -215.2240    218.925     -0.983      0.326    -644.657     214.209
# RentQrange              230.2833    108.355      2.125      0.034      17.740     442.827
# MedRent                 455.7456    392.582      1.161      0.246    -314.325    1225.816
# MedRentPctHousInc      -120.1949    119.964     -1.002      0.317    -355.512     115.122
# MedOwnCostPctInc       -102.3205    126.558     -0.808      0.419    -350.572     145.931
# MedOwnCostPctIncNoMtg  -273.5546    136.979     -1.997      0.046    -542.246      -4.864
# NumInShelters          5101.6955   1854.166      2.751      0.006    1464.648    8738.743
# NumStreet               743.2088   1826.602      0.407      0.684   -2839.769    4326.187
# PctForeignBorn          544.6236    479.571      1.136      0.256    -396.081    1485.328
# PctBornSameState         -7.6345    133.220     -0.057      0.954    -268.952     253.683
# PctSameHouse85            4.5125    205.940      0.022      0.983    -399.450     408.475
# PctSameCity85            32.7734    154.127      0.213      0.832    -269.555     335.101
# PctSameState85          188.3149    245.466      0.767      0.443    -293.180     669.809
# LandArea                -89.5230    355.567     -0.252      0.801    -786.987     607.941
# PopDens                -504.8238    272.158     -1.855      0.064   -1038.676      29.028
# PctUsePubTrans          -41.3419    187.669     -0.220      0.826    -409.465     326.781
# LemasPctOfficDrugUn     399.5832    168.249      2.375      0.018      69.553     729.613
# ==============================================================================
# Omnibus:                      490.004   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2867.866
# Skew:                           1.306   Prob(JB):                         0.00
# Kurtosis:                       9.027   Cond. No.                     1.16e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.78e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Adding constant variable to test dataframe
X_test_lm = sm.add_constant(X_test)
y_pred = lr.predict(X_test_lm)

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure(figsize=(15,8))
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)  
plt.show()

# %%
print("RMSE of test set is {}".format(np.sqrt(mean_squared_error(y_test, y_pred))))
print("R2 score of test set is {}".format(r2_score(y_test, y_pred)))
# Out:
# RMSE of test set is 375.17011348806153
# R2 score of test set is 0.5955585167635717

# %% [markdown]
# # Feature reduction

# %% [markdown]
# ### Based on correlation matrix

# %%
corr = df.corr()
corr.head()
# Out:
#                   state  population  householdsize  racepctblack  \
# state          1.000000   -0.029918      -0.049922     -0.054179
# population    -0.029918    1.000000      -0.019981      0.119854
# householdsize -0.049922   -0.019981       1.000000     -0.056414
# racepctblack  -0.054179    0.119854      -0.056414      1.000000
# racePctWhite   0.207033   -0.169166      -0.242781     -0.803894
#
#                racePctWhite  racePctAsian  racePctHisp  agePct12t21  \
# state              0.207033     -0.288945    -0.163117     0.100238
# population        -0.169166      0.090208     0.086982    -0.008923
# householdsize     -0.242781      0.190105     0.500892     0.486331
# racepctblack      -0.803894     -0.090069    -0.079059     0.089593
# racePctWhite       1.000000     -0.289968    -0.414166    -0.140684
#
#                agePct12t29  agePct16t24  agePct65up  numbUrban  pctUrban  \
# state             0.048482     0.061861   -0.008085  -0.032551 -0.099737
# population        0.046036     0.017482   -0.045355   0.998995  0.114537
# householdsize     0.376947     0.308143   -0.577270  -0.020522 -0.014662
# racepctblack      0.119057     0.087543    0.035011   0.119063  0.004527
# racePctWhite     -0.215621    -0.123896    0.136809  -0.169576 -0.054400
#
#                medIncome  pctWWage  pctWFarmSelf  pctWInvInc  pctWSocSec  \
# state          -0.139357  0.006004      0.089844    0.053167    0.051233
# population     -0.049027 -0.007607     -0.064685   -0.079206   -0.058257
# householdsize   0.181059  0.417834      0.164318   -0.164633   -0.434644
# racepctblack   -0.340253 -0.211859     -0.145080   -0.488093    0.100835
# racePctWhite    0.293470  0.108838      0.094862    0.593415    0.071096
#
#                pctWPubAsst  pctWRetire  medFamInc  perCapInc  whitePerCap  \
# state            -0.096905    0.011122  -0.127288  -0.151175    -0.185448
# population        0.102717   -0.059051  -0.052909  -0.021724     0.030418
# householdsize     0.135027   -0.318199   0.091563  -0.130590    -0.128959
# racepctblack      0.438303   -0.069742  -0.340995  -0.263897    -0.101097
# racePctWhite     -0.585514    0.222639   0.327677   0.287915     0.117542
#
#                blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  \
# state            -0.097281     -0.036567    -0.063510    -0.083988
# population       -0.025298     -0.009580    -0.036956    -0.023606
# householdsize     0.032877     -0.003111    -0.058253     0.015516
# racepctblack     -0.193267     -0.037702    -0.104708    -0.091403
# racePctWhite      0.129899      0.033980     0.139844     0.100004
#
#                HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# state           -0.086741    -0.009748        0.040667        -0.005464
# population      -0.048526     0.988444        0.086877         0.034136
# householdsize   -0.077782    -0.012179        0.078581         0.245318
# racepctblack    -0.136026     0.155612        0.473351         0.231797
# racePctWhite     0.196434    -0.195098       -0.531789        -0.456557
#
#                PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  \
# state             -0.003254    -0.047110      -0.034766  -0.016770
# population         0.045206    -0.003315       0.081596  -0.014364
# householdsize      0.136561    -0.039716       0.170725   0.081921
# racepctblack       0.347826    -0.176438       0.384263  -0.263954
# racePctWhite      -0.485498     0.215511      -0.519252   0.251071
#
#                PctEmplManu  PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  \
# state             0.080694         0.078279      0.096208         -0.055305
# population       -0.057673         0.013357     -0.015580         -0.006115
# householdsize     0.029983        -0.071258      0.087696         -0.087931
# racepctblack     -0.018136         0.098149      0.224080         -0.193809
# racePctWhite      0.035261         0.019681     -0.269624          0.258503
#
#                MalePctDivorce  MalePctNevMarr  FemalePctDiv  TotalPctDiv  \
# state               -0.094256       -0.065502     -0.172726    -0.136072
# population           0.098186        0.125998      0.120862     0.111794
# householdsize       -0.430513        0.198095     -0.329183    -0.392025
# racepctblack         0.395937        0.263314      0.424183     0.427359
# racePctWhite        -0.338431       -0.347534     -0.444517    -0.405734
#
#                PersPerFam  PctFam2Par  PctKids2Par  PctYoungKids2Par  \
# state           -0.053491    0.078507     0.104620          0.047056
# population       0.054831   -0.143653    -0.147788         -0.117659
# householdsize    0.834270    0.259384     0.184849          0.178593
# racepctblack     0.043526   -0.698739    -0.730886         -0.656002
# racePctWhite    -0.396216    0.641073     0.702048          0.602040
#
#                PctTeen2Par  PctWorkMomYoungKids  PctWorkMom  \
# state             0.090378            -0.000318    0.039829
# population       -0.138804            -0.048912   -0.078329
# householdsize     0.247937            -0.225003   -0.274545
# racepctblack     -0.689285             0.172997    0.082237
# racePctWhite      0.616726             0.006455    0.155309
#
#                NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# state                    -0.013433            -0.109976 -0.047403
# population                0.969195             0.191859  0.936985
# householdsize            -0.013821             0.042490  0.024470
# racepctblack              0.181284             0.804524  0.043456
# racePctWhite             -0.201451            -0.798226 -0.124134
#
#                PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  \
# state               -0.059529     -0.095662     -0.102823      -0.104522
# population           0.059698      0.074001      0.090960       0.105519
# householdsize        0.040969      0.063113      0.075254       0.108282
# racepctblack         0.156847      0.187128      0.219079       0.243196
# racePctWhite        -0.219282     -0.285590     -0.347926      -0.410470
#
#                PctRecentImmig  PctRecImmig5  PctRecImmig8  PctRecImmig10  \
# state               -0.290528     -0.301561     -0.311068      -0.309313
# population           0.141773      0.144575      0.150282       0.151284
# householdsize        0.299475      0.321611      0.327684       0.340059
# racepctblack        -0.044055     -0.035334     -0.031330      -0.026799
# racePctWhite        -0.396110     -0.419459     -0.435960      -0.446585
#
#                PctSpeakEnglOnly  PctNotSpeakEnglWell  PctLargHouseFam  \
# state                  0.203121            -0.206453        -0.139777
# population            -0.112085             0.116945         0.100734
# householdsize         -0.450803             0.453980         0.684243
# racepctblack           0.101061            -0.053654         0.145416
# racePctWhite           0.404685            -0.433832        -0.543140
#
#                PctLargHouseOccup  PersPerOccupHous  PersPerOwnOccHous  \
# state                  -0.125855         -0.078051           0.000578
# population              0.062569         -0.012390           0.006475
# householdsize           0.741631          0.878850           0.812932
# racepctblack            0.074473         -0.100836          -0.149839
# racePctWhite           -0.467185         -0.229072          -0.134575
#
#                PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# state                   -0.166847         0.077478         -0.241898
# population               0.021423        -0.152697          0.114637
# householdsize            0.732483         0.105920          0.549812
# racepctblack             0.098537        -0.366600          0.112186
# racePctWhite            -0.469633         0.503944         -0.592445
#
#                PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  \
# state               -0.156130  0.098061   -0.032012      0.026614
# population           0.135195 -0.111608    0.925067     -0.021070
# householdsize       -0.291988  0.188001   -0.091015      0.216394
# racepctblack         0.227388 -0.138967    0.183444     -0.185984
# racePctWhite        -0.364733  0.283068   -0.200318      0.123437
#
#                PctHousOwnOcc  PctVacantBoarded  PctVacMore6Mos  \
# state               0.039105          0.074035        0.265065
# population         -0.155522          0.144962       -0.032800
# householdsize       0.160913          0.059062       -0.035391
# racepctblack       -0.332644          0.475089        0.165820
# racePctWhite        0.438295         -0.445982        0.005200
#
#                MedYrHousBuilt  PctHousNoPhone  PctWOFullPlumb  OwnOccLowQuart  \
# state               -0.135216        0.101135        0.035710       -0.362619
# population          -0.052455        0.035408        0.076615        0.013098
# householdsize        0.235763        0.011580        0.177293        0.109484
# racepctblack        -0.088919        0.463550        0.253720       -0.267222
# racePctWhite         0.021606       -0.472221       -0.377743        0.086562
#
#                OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  RentLowQ  \
# state             -0.361667      -0.356159     -0.282015 -0.284938
# population         0.021866       0.037633      0.073552 -0.000583
# householdsize      0.098424       0.084929      0.027318  0.137243
# racepctblack      -0.251823      -0.235727     -0.139428 -0.307849
# racePctWhite       0.071953       0.062168      0.008857  0.122810
#
#                RentMedian  RentHighQ  RentQrange   MedRent  MedRentPctHousInc  \
# state           -0.303545  -0.307146   -0.239283 -0.296125          -0.273433
# population       0.001442   0.014700    0.035454 -0.007353           0.061054
# householdsize    0.153729   0.167739    0.161681  0.165025           0.135271
# racepctblack    -0.293102  -0.283565   -0.145319 -0.269213           0.193309
# racePctWhite     0.123819   0.119014    0.071788  0.123516          -0.337486
#
#                MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  \
# state                 -0.354721               0.187324      -0.015973
# population             0.046054              -0.007638       0.930328
# householdsize          0.245061              -0.100862      -0.033365
# racepctblack          -0.060333               0.217051       0.112560
# racePctWhite          -0.174969              -0.065464      -0.142072
#
#                NumStreet  PctForeignBorn  PctBornSameState  PctSameHouse85  \
# state          -0.023962       -0.331505          0.322627        0.139254
# population      0.921038        0.133113         -0.067765       -0.033408
# householdsize  -0.012173        0.338059         -0.060116       -0.072199
# racepctblack    0.061265       -0.094644          0.095896       -0.034314
# racePctWhite   -0.099792       -0.377356          0.111693        0.157403
#
#                PctSameCity85  PctSameState85  LandArea   PopDens  \
# state               0.050027        0.111097 -0.060734 -0.108040
# population          0.016860       -0.028155  0.196397  0.213941
# householdsize      -0.125074       -0.049700 -0.004956  0.031585
# racepctblack        0.063746       -0.000693  0.040304  0.094314
# racePctWhite       -0.026029        0.032871 -0.045795 -0.320328
#
#                PctUsePubTrans  LemasPctOfficDrugUn  ViolentCrimesPerPop
# state               -0.014821            -0.055771            -0.202935
# population           0.319666             0.201392             0.212354
# householdsize       -0.053731            -0.083771            -0.020110
# racepctblack         0.172936             0.245968             0.628368
# racePctWhite        -0.228876            -0.257610            -0.676849

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False

# %%
selected_columns = df.columns[columns]
selected_columns.shape
# Out:
# (69,)

# %% [markdown]
# #### Selected 69 features based on the correlation matrix

# %%
for index,i in enumerate(selected_columns):
    print(index + 1,' : ',i)
# Out:
# 1  :  state
# 2  :  population
# 3  :  householdsize
# 4  :  racepctblack
# 5  :  racePctWhite
# 6  :  racePctAsian
# 7  :  racePctHisp
# 8  :  agePct12t21
# 9  :  agePct12t29
# 10  :  agePct65up
# 11  :  pctUrban
# 12  :  medIncome
# 13  :  pctWWage
# 14  :  pctWFarmSelf
# 15  :  pctWInvInc
# 16  :  pctWPubAsst
# 17  :  pctWRetire
# 18  :  blackPerCap
# 19  :  indianPerCap
# 20  :  AsianPerCap
# 21  :  OtherPerCap
# 22  :  HispPerCap
# 23  :  PctPopUnderPov
# 24  :  PctLess9thGrade
# 25  :  PctBSorMore
# 26  :  PctUnemployed
# 27  :  PctEmploy
# 28  :  PctEmplManu
# 29  :  PctEmplProfServ
# 30  :  PctOccupManu
# 31  :  MalePctDivorce
# 32  :  MalePctNevMarr
# 33  :  PersPerFam
# 34  :  PctFam2Par
# 35  :  PctWorkMomYoungKids
# 36  :  PctWorkMom
# 37  :  PctKidsBornNeverMar
# 38  :  PctImmigRecent
# 39  :  PctRecentImmig
# 40  :  PctSpeakEnglOnly
# 41  :  PctNotSpeakEnglWell
# 42  :  PctLargHouseFam
# 43  :  PersPerRentOccHous
# 44  :  PctPersOwnOccup
# 45  :  PctPersDenseHous
# 46  :  PctHousLess3BR
# 47  :  MedNumBR
# 48  :  PctHousOccup
# 49  :  PctVacantBoarded
# 50  :  PctVacMore6Mos
# 51  :  MedYrHousBuilt
# 52  :  PctHousNoPhone
# 53  :  PctWOFullPlumb
# 54  :  OwnOccLowQuart
# 55  :  OwnOccQrange
# 56  :  RentLowQ
# 57  :  RentQrange
# 58  :  MedRentPctHousInc
# 59  :  MedOwnCostPctInc
# 60  :  MedOwnCostPctIncNoMtg
# 61  :  PctBornSameState
# 62  :  PctSameHouse85
# 63  :  PctSameCity85
# 64  :  PctSameState85
# 65  :  LandArea
# 66  :  PopDens
# 67  :  PctUsePubTrans
# 68  :  LemasPctOfficDrugUn
# 69  :  ViolentCrimesPerPop

# %%
data_corr = df[selected_columns]

# %%
y = data_corr['ViolentCrimesPerPop']
X = data_corr.drop(['ViolentCrimesPerPop'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
numerical_columns = X.drop('state',axis=1).columns.tolist()

# %%
X[numerical_columns] = scaler.fit_transform(X[numerical_columns])
# Out:
# /home/bat/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm = sm.add_constant(X_train)

# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit()

# %%
# Print a summary of the linear regression model obtained
print(lr.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.669
# Model:                             OLS   Adj. R-squared:                  0.655
# Method:                  Least Squares   F-statistic:                     45.43
# Date:                 Thu, 23 May 2019   Prob (F-statistic):          1.05e-314
# Time:                         20:38:24   Log-Likelihood:                -11638.
# No. Observations:                 1595   AIC:                         2.341e+04
# Df Residuals:                     1526   BIC:                         2.378e+04
# Df Model:                           68
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1299.2227    803.736      1.616      0.106    -277.321    2875.766
# state                    -3.8436      0.923     -4.164      0.000      -5.654      -2.033
# population              706.1033    371.712      1.900      0.058     -23.016    1435.223
# householdsize           242.2464    432.073      0.561      0.575    -605.274    1089.766
# racepctblack            687.2254    344.638      1.994      0.046      11.211    1363.240
# racePctWhite            -91.6163    324.880     -0.282      0.778    -728.875     545.642
# racePctAsian             37.0038    304.671      0.121      0.903    -560.615     634.623
# racePctHisp             -68.9630    309.591     -0.223      0.824    -676.233     538.307
# agePct12t21             811.2680    398.352      2.037      0.042      29.893    1592.643
# agePct12t29           -1614.5576    544.108     -2.967      0.003   -2681.837    -547.278
# agePct65up              486.1365    482.750      1.007      0.314    -460.787    1433.060
# pctUrban                111.3509     29.764      3.741      0.000      52.968     169.734
# medIncome                -1.7063    458.841     -0.004      0.997    -901.731     898.319
# pctWWage               -682.6637    375.511     -1.818      0.069   -1419.237      53.909
# pctWFarmSelf             83.7945    115.477      0.726      0.468    -142.716     310.305
# pctWInvInc             -322.4560    220.416     -1.463      0.144    -754.807     109.895
# pctWPubAsst             209.9112    180.405      1.164      0.245    -143.958     563.780
# MedOwnCostPctInc        -21.3715    122.157     -0.175      0.861    -260.984     218.241
# MedOwnCostPctIncNoMtg  -359.9017    132.721     -2.712      0.007    -620.237     -99.566
# PctBornSameState       -100.7008    122.897     -0.819      0.413    -341.765     140.363
# PctSameHouse85          154.7377    196.031      0.789      0.430    -229.780     539.256
# PctSameCity85            -1.7642    152.749     -0.012      0.991    -301.385     297.857
# PctSameState85          278.9087    229.245      1.217      0.224    -170.760     728.578
# LandArea                129.4279    332.954      0.389      0.698    -523.668     782.524
# PopDens                -425.0657    257.533     -1.651      0.099    -930.222      80.091
# PctUsePubTrans           92.3232    179.009      0.516      0.606    -258.807     443.453
# LemasPctOfficDrugUn     385.8925    163.754      2.357      0.019      64.686     707.099
# ==============================================================================
# Omnibus:                      470.012   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2531.227
# Skew:                           1.273   Prob(JB):                         0.00
# Kurtosis:                       8.622   Cond. No.                     2.83e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Adding constant variable to test dataframe
X_test_lm = sm.add_constant(X_test)
y_pred = lr.predict(X_test_lm)

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure(figsize=(15,8))
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)  
plt.show()

# %%
print("RMSE of test set is {}".format(np.sqrt(mean_squared_error(y_test, y_pred))))
print("R2 score of test set is {}".format(r2_score(y_test, y_pred)))
# Out:
# RMSE of test set is 361.7518865591507
# R2 score of test set is 0.6239714374912785

# %% [markdown]
# ## Selecting columns based on p-value

# %%
selected_columns = selected_columns[:-1].values

# %%
import statsmodels.formula.api as sm
def backwardElimination(x, Y, sl, columns):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(Y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
                    columns = np.delete(columns, j)
                    
    regressor_OLS.summary()
    return x, columns

# %%
SL = 0.05
data_modeled, selected_columns = backwardElimination(data_corr.iloc[:,:-1].values,
                                                     data_corr.iloc[:,-1].values, SL, selected_columns)

# %% [markdown]
# ## Top 23 features are choosen based on the p-value

# %%
for index,i in enumerate(selected_columns):
    print(index + 1,' : ',i)
# Out:
# 1  :  state
# 2  :  population
# 3  :  racepctblack
# 4  :  agePct12t29
# 5  :  pctUrban
# 6  :  pctWWage
# 7  :  pctWInvInc
# 8  :  pctWRetire
# 9  :  OtherPerCap
# 10  :  PctLess9thGrade
# 11  :  PctEmploy
# 12  :  MalePctDivorce
# 13  :  MalePctNevMarr
# 14  :  PctWorkMom
# 15  :  PctKidsBornNeverMar
# 16  :  PctPersDenseHous
# 17  :  PctHousOccup
# 18  :  PctVacantBoarded
# 19  :  MedYrHousBuilt
# 20  :  OwnOccLowQuart
# 21  :  RentQrange
# 22  :  MedOwnCostPctIncNoMtg
# 23  :  LemasPctOfficDrugUn

# %%
result = pd.DataFrame()
result['ViolentCrimesPerPop'] = data_corr.iloc[:,-1]

# %%
data = pd.DataFrame(data = data_modeled, columns = selected_columns)

# %%
data.head()
# Out:
#    state  population  racepctblack  agePct12t29  pctUrban  pctWWage  \
# 0   26.0     11980.0          1.37        21.44     100.0     89.24
# 1   33.0     23123.0          0.80        21.30     100.0     78.99
# 2   32.0     29344.0          0.74        25.88     100.0     82.00
# 3   29.0     16656.0          1.70        25.20       0.0     68.15
# 4   21.0    140494.0          2.51        32.89     100.0     75.78
#
#    pctWInvInc  pctWRetire  OtherPerCap  PctLess9thGrade  PctEmploy  \
# 0       70.20       18.39       5115.0             5.81      64.55
# 1       64.11       22.85       5250.0             5.61      61.96
# 2       55.73       14.56       5954.0             2.80      69.80
# 3       38.95       18.33       2451.0            11.05      54.74
# 4       41.15       14.09       7192.0             8.76      59.02
#
#    MalePctDivorce  MalePctNevMarr  PctWorkMom  PctKidsBornNeverMar  \
# 0            3.67           26.38       58.88                 0.36
# 1            4.23           27.99       62.43                 0.24
# 2           10.10           25.78       74.19                 0.88
# 3           10.98           28.15       70.27                 3.84
# 4           11.40           33.32       70.52                 1.58
#
#    PctPersDenseHous  PctHousOccup  PctVacantBoarded  MedYrHousBuilt  \
# 0              0.39         98.37              3.12          1959.0
# 1              1.01         97.15              0.00          1958.0
# 2              2.03         95.68              0.92          1976.0
# 3              1.21         91.19              2.54          1939.0
# 4              2.11         91.81              2.09          1966.0
#
#    OwnOccLowQuart  RentQrange  MedOwnCostPctIncNoMtg  LemasPctOfficDrugUn
# 0        215900.0       316.0                   14.0                  0.0
# 1        136300.0       205.0                   12.5                  0.0
# 2         74700.0       150.0                   11.6                  0.0
# 3         36400.0       114.0                   14.5                  0.0
# 4         37700.0       134.0                   11.7                  0.0

# %%
fig = plt.figure(figsize = (20, 25))
j = 0
for i in data.columns:
    plt.subplot(10, 4, j+1)
    j += 1
    sns.distplot(data[i], color='g')
fig.suptitle('Crime data Analysis')
fig.tight_layout()
fig.subplots_adjust(top=0.95)
plt.show()

# %%
# y = result['ViolentCrimesPerPop'].values
# X = data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 23 columns):
# state                    1994 non-null float64
# population               1994 non-null float64
# racepctblack             1994 non-null float64
# agePct12t29              1994 non-null float64
# pctUrban                 1994 non-null float64
# pctWWage                 1994 non-null float64
# pctWInvInc               1994 non-null float64
# pctWRetire               1994 non-null float64
# OtherPerCap              1994 non-null float64
# PctLess9thGrade          1994 non-null float64
# PctEmploy                1994 non-null float64
# MalePctDivorce           1994 non-null float64
# MalePctNevMarr           1994 non-null float64
# PctWorkMom               1994 non-null float64
# PctKidsBornNeverMar      1994 non-null float64
# PctPersDenseHous         1994 non-null float64
# PctHousOccup             1994 non-null float64
# PctVacantBoarded         1994 non-null float64
# MedYrHousBuilt           1994 non-null float64
# OwnOccLowQuart           1994 non-null float64
# RentQrange               1994 non-null float64
# MedOwnCostPctIncNoMtg    1994 non-null float64
# LemasPctOfficDrugUn      1994 non-null float64
# dtypes: float64(23)
# memory usage: 358.4 KB

# %%
data['ViolentCrimesPerPop']  = result['ViolentCrimesPerPop'].values

# %%
y = data['ViolentCrimesPerPop']
X = data.drop(['ViolentCrimesPerPop'],axis=1)

# %%
X.shape
# Out:
# (1994, 23)

# %%
y.shape
# Out:
# (1994,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# .drop('state',axis=1)
numerical_columns = X.columns.tolist()

# %%
X[numerical_columns] = scaler.fit_transform(X[numerical_columns])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm = sm.add_constant(X_train)

# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit()

# %% [markdown]
# ## P-value for each features and other statistics

# %%
# Check the summary
print(lr.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.661
# Model:                             OLS   Adj. R-squared:                  0.656
# Method:                  Least Squares   F-statistic:                     133.1
# Date:                 Thu, 23 May 2019   Prob (F-statistic):               0.00
# Time:                         20:38:40   Log-Likelihood:                -11658.
# No. Observations:                 1595   AIC:                         2.336e+04
# Df Residuals:                     1571   BIC:                         2.349e+04
# Df Model:                           23
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1380.7006    205.021      6.734      0.000     978.557    1782.844
# state                  -169.4112     39.023     -4.341      0.000    -245.954     -92.869
# population              766.9473    340.185      2.255      0.024      99.683    1434.212
# racepctblack            786.7562    124.429      6.323      0.000     542.692    1030.820
# agePct12t29            -871.3411    275.879     -3.158      0.002   -1412.471    -330.211
# pctUrban                 98.2527     25.706      3.822      0.000      47.830     148.675
# pctWWage              -1065.5425    227.817     -4.677      0.000   -1512.400    -618.685
# pctWInvInc             -453.1662    149.255     -3.036      0.002    -745.927    -160.405
# pctWRetire             -399.0148    125.729     -3.174      0.002    -645.629    -152.401
# OtherPerCap             483.6214    180.196      2.684      0.007     130.171     837.072
# PctLess9thGrade        -283.1753    139.578     -2.029      0.043    -556.955      -9.396
# PctEmploy               518.1491    202.474      2.559      0.011     121.002     915.296
# MalePctDivorce          440.1475     92.524      4.757      0.000     258.664     621.631
# MalePctNevMarr          792.3819    222.219      3.566      0.000     356.504    1228.260
# PctWorkMom             -346.0637     92.382     -3.746      0.000    -527.270    -164.858
# PctKidsBornNeverMar    1473.8942    183.802      8.019      0.000    1113.371    1834.417
# PctPersDenseHous        930.7237    180.625      5.153      0.000     576.433    1285.014
# PctHousOccup           -298.9515    133.729     -2.235      0.026    -561.258     -36.644
# PctVacantBoarded        402.4692    137.899      2.919      0.004     131.983     672.955
# MedYrHousBuilt           17.2634     58.372      0.296      0.767     -97.231     131.758
# OwnOccLowQuart         -446.9141    127.667     -3.501      0.000    -697.329    -196.499
# RentQrange              346.2565    122.532      2.826      0.005     105.913     586.600
# MedOwnCostPctIncNoMtg  -407.8887    106.657     -3.824      0.000    -617.095    -198.683
# LemasPctOfficDrugUn     388.4045    159.406      2.437      0.015      75.734     701.075
# ==============================================================================
# Omnibus:                      462.130   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2430.625
# Skew:                           1.257   Prob(JB):                         0.00
# Kurtosis:                       8.500   Cond. No.                         89.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Adding constant variable to test dataframe

X_test_lm = sm.add_constant(X_test)
y_pred = lr.predict(X_test_lm)

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure(figsize=(15,8))
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)  
plt.show()

# %%
print("RMSE of test set is {}".format(np.sqrt(mean_squared_error(y_test, y_pred))))
print("R2 score of test set is {}".format(r2_score(y_test, y_pred)))
# Out:
# RMSE of test set is 358.0951818976042
# R2 score of test set is 0.6315350513840485

# %% [markdown]
# ## Residual plots

# %%
fig = plt.figure(figsize=(15,8))

# pass in the model as the first parameter, then specify the 
# predictor variable we want to analyze
fig = sm.graphics.plot_regress_exog(lr, "population", fig=fig)
plt.show()

# %%
ax = sns.regplot(x="population", y="ViolentCrimesPerPop", data=df)
plt.title('Unnormalised plot')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(lr, "pctUrban", fig=fig)
plt.show()

# %%
ax = sns.regplot(x="pctUrban", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(lr, "MedYrHousBuilt", fig=fig)
plt.show()

# %%
ax = sns.regplot(x="MedYrHousBuilt", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(lr, "MalePctDivorce", fig=fig)
plt.show()

# %%
ax = sns.regplot(x="MalePctDivorce", y="ViolentCrimesPerPop", data=df)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(lr, "PctHousOccup", fig=fig)
plt.show()

# %%
ax = sns.regplot(x="PctHousOccup", y="ViolentCrimesPerPop", data=df)
plt.show()

# %% [markdown]
# ## Polynomial or Non-linear regression

# %%
from sklearn.preprocessing import PolynomialFeatures

def create_polynomial_regression_model(degree):
    "Creates a polynomial regression model for the given degree"

    poly_features = PolynomialFeatures(degree=degree)

    # transforms the existing features to higher degree features.
    X_train_poly = poly_features.fit_transform(X_train)

    # fit the transformed features to Linear Regression
    poly_model = LinearRegression()
    poly_model.fit(X_train_poly, y_train)

    # predicting on training data-set
    y_train_predicted = poly_model.predict(X_train_poly)

    # predicting on test data-set
    y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))

    # evaluating the model on training dataset
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predicted))
    r2_train = r2_score(y_train, y_train_predicted)

    # evaluating the model on test dataset
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
    r2_test = r2_score(y_test, y_test_predict)


    print("The model performance for the test set")
    print("-------------------------------------------")
    print("RMSE of test set is {}".format(rmse_test))
    print("R2 score of test set is {}".format(r2_test))

# %%
create_polynomial_regression_model(2)
# Out:
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 451.3281482688816
# R2 score of test set is 0.4146925315401805

# %%
#y = df['ViolentCrimesPerPop']
#X = df.drop(['ViolentCrimesPerPop'],axis=1)

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
X.head()
# Out:
#       state  population  racepctblack  agePct12t29  pctUrban  pctWWage  \
# 0  0.577778    0.000270      0.014172     0.197284       1.0  0.886357
# 1  0.733333    0.001794      0.008276     0.194994       1.0  0.728519
# 2  0.711111    0.002645      0.007655     0.269917       1.0  0.774869
# 3  0.644444    0.000910      0.017586     0.258793       0.0  0.561595
# 4  0.466667    0.017845      0.025965     0.384590       1.0  0.679088
#
#    pctWInvInc  pctWRetire  OtherPerCap  PctLess9thGrade  PctEmploy  \
# 0    0.767780    0.355054     0.037336         0.112900   0.663826
# 1    0.692715    0.461118     0.038321         0.108875   0.620551
# 2    0.589424    0.263971     0.043460         0.052324   0.751546
# 3    0.382596    0.353627     0.017891         0.218354   0.499916
# 4    0.409713    0.252794     0.052496         0.172268   0.571429
#
#    MalePctDivorce  MalePctNevMarr  PctWorkMom  PctKidsBornNeverMar  \
# 0        0.090802        0.222845    0.357022             0.014882
# 1        0.123821        0.247899    0.431885             0.009921
# 2        0.469929        0.213508    0.679882             0.036379
# 3        0.521816        0.250389    0.597216             0.158743
# 4        0.546580        0.330843    0.602488             0.065316
#
#    PctPersDenseHous  PctHousOccup  PctVacantBoarded  MedYrHousBuilt  \
# 0          0.005720      0.989761          0.078215        0.416667
# 1          0.016151      0.969933          0.000000        0.395833
# 2          0.033311      0.946043          0.023063        0.770833
# 3          0.019515      0.873070          0.063675        0.000000
# 4          0.034657      0.883146          0.052394        0.562500
#
#    OwnOccLowQuart  RentQrange  MedOwnCostPctIncNoMtg  LemasPctOfficDrugUn
# 0        0.413379    0.393524               0.293233                  0.0
# 1        0.249019    0.255293               0.180451                  0.0
# 2        0.121825    0.186800               0.112782                  0.0
# 3        0.042742    0.141968               0.330827                  0.0
# 4        0.045426    0.166874               0.120301                  0.0

# %%
X.shape
# Out:
# (1994, 23)

# %%
y.shape
# Out:
# (1994,)

# %%
X_train.shape
# Out:
# (1595, 23)

# %%
y_train.shape
# Out:
# (1595,)

# %% [markdown]
# ## Ridge regression with 5-fold cross-validation and gridsearch

# %%
ridge = Ridge()
parameters = {'alpha':[1e-15,1e-10,1e-8,1e-4,1e-3,1e-2,1,5,10,20]}

ridge_regressor = GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1, 5, 10, 20]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
from sklearn import linear_model


# Compute paths

alphas = [1e-15,1e-10,1e-8,1e-4,1e-3,1e-2,1,5,10,20]
coefs = []
for a in alphas:
    ridge = linear_model.Ridge(alpha=a, fit_intercept=False)
    ridge.fit(X_train, y_train)
    coefs.append(ridge.coef_)

# #############################################################################
# Display results
plt.figure(figsize=(15,8))
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()

# %% [markdown]
# Below we'll run a ridge regression and see how score varies with different alphas. This will show how picking a different alpha score changes the R2.

# %%
# Create an array of alphas and lists to store scores
alpha_space = np.logspace(-4, 1,50)
ridge_scores = []
ridge_scores_std = []

# Create a ridge regressor: ridge
ridge = Ridge(normalize=False)

# Compute scores over range of alphas
for alpha in alpha_space:

    # Specify the alpha value to use: ridge.alpha
    ridge.alpha = alpha
    
    # Perform 10-fold CV: ridge_cv_scores
    ridge_cv_scores = cross_val_score(ridge, X_train, y_train, cv=5)
    
    # Append the mean of ridge_cv_scores to ridge_scores
    ridge_scores.append(np.mean(ridge_cv_scores))
    
    # Append the std of ridge_cv_scores to ridge_scores_std
    ridge_scores_std.append(np.std(ridge_cv_scores))

# Use this function to create a plot    
def display_plot(cv_scores, cv_scores_std):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.plot(alpha_space, cv_scores)

    std_error = cv_scores_std / np.sqrt(10)

    ax.fill_between(alpha_space, cv_scores + std_error, cv_scores - std_error, alpha=0.2)
    ax.set_ylabel('CV Score +/- Std Error')
    ax.set_xlabel('Alpha')
    ax.axhline(np.max(cv_scores), linestyle='--', color='.5')
    ax.set_xlim([alpha_space[0], alpha_space[-1]])
    ax.set_xscale('log')
    plt.show()

# Display the plot
display_plot(ridge_scores, ridge_scores_std)

# %% [markdown]
# ### FInd best params for alpha and MSE score with visualisation also

# %%
print(ridge_regressor.best_params_)
print(-ridge_regressor.best_score_)
# Out:
# {'alpha': 1}
# 136079.3434254652

# %% [markdown]
# ### Here best generalised parameter (lambda) is `1`.

# %%
ridge = Ridge(alpha=1)

#ridge_regressor = GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_pred = ridge.predict(X_test)

# %%
print('R2-score in Ridge regression : ',r2_score(y_test,y_pred))
# Out:
# R2-score in Ridge regression :  0.6314228094363009

# %% [markdown]
# ## 2. Weighted Linear regression

# %%
X.shape
# Out:
# (1994, 23)

# %%
y.shape
# Out:
# (1994,)

# %%
from __future__ import print_function
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.iolib.table import (SimpleTable, default_txt_fmt)
np.random.seed(1024)

# %%
#nsample = 1994
nsample = 1595
w = np.ones(nsample)
w[nsample * 6//10:] = 3

# %%
w.shape
# Out:
# (1595,)

# %%
X_train.shape
# Out:
# (1595, 23)

# %%
mod_wls = sm.WLS(y_train, X_train, weights=1./(w ** 2))
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                              WLS Regression Results
# ===============================================================================
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.815
# Model:                             WLS   Adj. R-squared:                  0.813
# Method:                  Least Squares   F-statistic:                     301.7
# Date:                 Thu, 23 May 2019   Prob (F-statistic):               0.00
# Time:                         20:39:00   Log-Likelihood:                -12043.
# No. Observations:                 1595   AIC:                         2.413e+04
# Df Residuals:                     1572   BIC:                         2.426e+04
# Df Model:                           23
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# state                  -189.6806     39.876     -4.757      0.000    -267.896    -111.465
# population              814.0441    619.188      1.315      0.189    -400.477    2028.565
# racepctblack            805.9393    125.675      6.413      0.000     559.431    1052.447
# agePct12t29            -396.5035    267.587     -1.482      0.139    -921.368     128.361
# pctUrban                 80.0995     26.113      3.067      0.002      28.880     131.319
# pctWWage               -881.1523    221.574     -3.977      0.000   -1315.765    -446.540
# pctWInvInc              -58.7727    131.832     -0.446      0.656    -317.358     199.813
# pctWRetire               28.3936    114.885      0.247      0.805    -196.950     253.737
# OtherPerCap             302.6494    179.696      1.684      0.092     -49.819     655.118
# PctLess9thGrade          68.3651    127.068      0.538      0.591    -180.876     317.606
# PctEmploy               664.7222    198.408      3.350      0.001     275.549    1053.895
# MalePctDivorce          784.2408     74.254     10.562      0.000     638.594     929.887
# MalePctNevMarr          619.9611    221.990      2.793      0.005     184.533    1055.389
# PctWorkMom             -350.4107     94.200     -3.720      0.000    -535.182    -165.640
# PctKidsBornNeverMar    1649.8980    183.626      8.985      0.000    1289.720    2010.076
# PctPersDenseHous        931.5440    176.154      5.288      0.000     586.022    1277.066
# PctHousOccup            165.1356    118.406      1.395      0.163     -67.115     397.386
# PctVacantBoarded        356.0627    132.616      2.685      0.007      95.939     616.187
# MedYrHousBuilt          107.8946     56.024      1.926      0.054      -1.995     217.784
# OwnOccLowQuart         -429.6523    125.383     -3.427      0.001    -675.587    -183.718
# RentQrange              505.0948    126.426      3.995      0.000     257.113     753.077
# MedOwnCostPctIncNoMtg   -99.3669    107.186     -0.927      0.354    -309.609     110.875
# LemasPctOfficDrugUn     184.1448    182.368      1.010      0.313    -173.565     541.854
# ==============================================================================
# Omnibus:                      672.821   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7022.764
# Skew:                           1.680   Prob(JB):                         0.00
# Kurtosis:                      12.715   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_pred = res_wls.predict(X_test)

# %%
print('R-squared error : ', r2_score(y_test,y_pred))
# Out:
# R-squared error :  0.6100639453314716

# %%
from sklearn.svm import SVR
from sklearn.linear_model import Lasso

# %%
lasso = Lasso(random_state=1)
#svr_lin = SVR(kernel='linear')
lasso.fit(X_train,y_train)
r2_score(y_test,lasso.predict(X_test))
# Out:
# 0.6183956517763234

# %% [markdown]
# ## XG boost model

# %%
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, GradientBoostingRegressor

# %%
# XGBoost

#model_xgb = xgb.XGBRegressor(n_estimators=3000, max_depth=2, learning_rate=0.1)
model_xgb = xgb.XGBRegressor(colsample_bytree=0.2, gamma=0.0, 
                             learning_rate=0.05, max_depth=6, 
                             min_child_weight=1.5, n_estimators=7200,
                             reg_alpha=0.9, reg_lambda=0.6,
                             subsample=0.2,seed=42, silent=1)

model_xgb.fit(X_train,y_train)#0.128
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.2, gamma=0.0, importance_type='gain',
#        learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1.5, missing=None, n_estimators=7200, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0.9,
#        reg_lambda=0.6, scale_pos_weight=1, seed=42, silent=1,
#        subsample=0.2)

# %%
r2_score(y_test,model_xgb.predict(X_test))
# Out:
# 0.6115698791182995

# %% [markdown]
# ## Gradient Boosting

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
GBoost.fit(X_train,y_train)
r2_score(y_test,GBoost.predict(X_test))
# Out:
# 0.6643234921206991

# %% [markdown]
# ## Light GBM

# %%
LightGB = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

LightGB.fit(X_train,y_train)
r2_score(y_test,LightGB.predict(X_test))
# Out:
# 0.6485959510545392

# %%
features = data.columns

# %% [markdown]
# ### Feature importance and rank with top 2 ensamble model

# %%
nrows = 1
ncols = 2
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize=(15,15))

names_regressors = [("LightGBM",LightGB),("GBoosting",GBoost)]

nregressors = 0
for row in range(nrows):
    for col in range(ncols):
        name = names_regressors[nregressors][0]
        regressor = names_regressors[nregressors][1]
        indices = np.argsort(regressor.feature_importances_)[::-1][:40]
        g = sns.barplot(y=features[indices][:40],x = regressor.feature_importances_[indices][:40] , orient='h',ax=axes[nregressors])
        g.set_xlabel("Relative importance",fontsize=12)
        g.set_ylabel("Features",fontsize=12)
        g.tick_params(labelsize=9)
        g.set_title(name + " feature importance")
        nregressors += 1

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %% [markdown]
# ## Comparison of R squared value
#
#
#
# * Linear Regression (Taking all the features)                              : `0.5955`
#
#
# * Linear Regression (Taking 68 features based on correlation matrix)       : `0.6239`
#
#
# * Linear Regression (Taking 23 features based on p-value)                  : `0.6315`
#
#
# * Polynomial regression (Taking 23 features based on p-value)              : `0.4146`
#
#
# * Ridge regression (Taking 23 features based on p-value)                   : `0.6314`
#
#
# * Weighted linear Regression (Taking 23 features based on p-value)         : `0.6183`
#
#
# * XG boost Regression (Taking 23 features based on p-value)         : `0.6115`
#
#
# * Gradient Boosting Regression (Taking 23 features based on p-value)         : `0.6643`
#
#
# * Light GBM Regression (Taking 23 features based on p-value)         : `0.6485`

# %% [markdown]
# ### In this method Ensamble regresssion model like gradient boosting and light gbm model gives better result than the other model.
#
# * We define our top 23 features which are most affected the predicted variable.
